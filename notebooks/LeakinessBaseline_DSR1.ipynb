# %% [markdown]
# <a href="https://colab.research.google.com/github/ShouryaBatra/psbs-research-project/blob/main/notebooks/LeakinessBaseline_DSR1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install datasets and baseline needs for getting datasets
# !pip install datasets==2.16.0
# !pip install transformers
# !pip install --upgrade transformers
# !pip install einops

# Load datasets
from datasets import load_dataset
import json

# !!! Create Train-Test Split - Need to determine dataset being used
train_dataset = load_dataset("", "main", split="train")
test_dataset = load_dataset("", "main", split="test")

# Creating a "debug" dataset for faster iteration
debug_dataset = train_dataset.select(range(0, 5))  # Select the first 5 for debug set
